# %%
import pandas as pd
import os
import csv
import matplotlib.pyplot as plt
from scipy.stats import linregress
import statsmodels.api as sm

# %%
life_expectancy = "./life_expectancy_by_state.csv"

# %%
life_expectancy_pd = pd.read_csv(life_expectancy)
life_expectancy_pd
# Out:
#                                              Location  \
# 0                                       United States
# 1                                             Alabama
# 2                                              Alaska
# 3                                             Arizona
# 4                                            Arkansas
# ..                                                ...
# 57  Arias E, Escobedo LA, Kennedy J, Fu C, Cisewsk...
# 58                                                NaN
# 59                                                NaN
# 60                                          Footnotes
# 61  1. Data for Maine and Wisconsin are not availa...
#
#     Life Expectancy at Birth (years)  Footnotes
# 0                               78.7        NaN
# 1                               75.5        NaN
# 2                               78.8        NaN
# 3                               79.9        NaN
# 4                               76.0        NaN
# ..                               ...        ...
# 57                               NaN        NaN
# 58                               NaN        NaN
# 59                               NaN        NaN
# 60                               NaN        NaN
# 61                               NaN        NaN
#
# [62 rows x 3 columns]

# %%
life_expectancy_pd.rename(columns = {'Location':'State', 'Life Expectancy at Birth (years)':'Longevity'}, inplace = True)

# %%
life_expectancy_pd = life_expectancy_pd[life_expectancy_pd.State != 'United States']
life_expectancy_pd.head()
# Out:
#         State  Longevity  Footnotes
# 1     Alabama       75.5        NaN
# 2      Alaska       78.8        NaN
# 3     Arizona       79.9        NaN
# 4    Arkansas       76.0        NaN
# 5  California       81.3        NaN

# %%
life_expectancy_pd.reset_index(drop=True, inplace=True)
life_expectancy_pd.head()
# Out:
#         State  Longevity  Footnotes
# 0     Alabama       75.5        NaN
# 1      Alaska       78.8        NaN
# 2     Arizona       79.9        NaN
# 3    Arkansas       76.0        NaN
# 4  California       81.3        NaN

# %%
life_expectancy_pd = life_expectancy_pd.drop('Footnotes', axis=1)
life_expectancy_pd
# Out:
#                                                 State  Longevity
# 0                                             Alabama       75.5
# 1                                              Alaska       78.8
# 2                                             Arizona       79.9
# 3                                            Arkansas       76.0
# 4                                          California       81.3
# ..                                                ...        ...
# 56  Arias E, Escobedo LA, Kennedy J, Fu C, Cisewsk...        NaN
# 57                                                NaN        NaN
# 58                                                NaN        NaN
# 59                                          Footnotes        NaN
# 60  1. Data for Maine and Wisconsin are not availa...        NaN
#
# [61 rows x 2 columns]

# %%
nonrows = life_expectancy_pd.iloc[51:61, :]
print(nonrows)
# Out:
#                                                 State  Longevity
# 51                                                NaN        NaN
# 52                                              Notes        NaN
# 53  State-level estimates are based on pooled 2011...        NaN
# 54                                                NaN        NaN
# 55                                            Sources        NaN
# 56  Arias E, Escobedo LA, Kennedy J, Fu C, Cisewsk...        NaN
# 57                                                NaN        NaN
# 58                                                NaN        NaN
# 59                                          Footnotes        NaN
# 60  1. Data for Maine and Wisconsin are not availa...        NaN

# %%
life_expectancy_pd = life_expectancy_pd.iloc[0:51, :]
life_expectancy_pd.head()
# Out:
#         State  Longevity
# 0     Alabama       75.5
# 1      Alaska       78.8
# 2     Arizona       79.9
# 3    Arkansas       76.0
# 4  California       81.3

# %%
life_expectancy_pd.shape
# Out:
# (51, 2)

# %%
alcohol = "./alcohol_consumption_by_state.csv"

# %%
alcohol_pd = pd.read_csv(alcohol)
alcohol_pd
# Out:
#                    State  alcoholConsumptionGallons  alcoholConsumptionLiters  \
# 0                   Utah                       1.34                      5.07
# 1          West Virginia                       1.76                      6.66
# 2               Arkansas                       1.80                      6.81
# 3               Oklahoma                       1.88                      7.12
# 4                 Kansas                       1.92                      7.27
# 5                Georgia                       1.94                      7.34
# 6               Kentucky                       1.98                      7.50
# 7                Alabama                       2.01                      7.61
# 8                   Ohio                       2.04                      7.72
# 9         North Carolina                       2.13                      8.06
# 10             Tennessee                       2.14                      8.10
# 11              Virginia                       2.14                      8.10
# 12              Maryland                       2.15                      8.14
# 13               Indiana                       2.17                      8.21
# 14              New York                       2.22                      8.40
# 15        South Carolina                       2.22                      8.40
# 16           Mississippi                       2.23                      8.44
# 17              Nebraska                       2.23                      8.44
# 18            Washington                       2.26                      8.56
# 19            New Mexico                       2.27                      8.59
# 20               Arizona                       2.31                      8.74
# 21              Illinois                       2.32                      8.78
# 22            California                       2.33                      8.82
# 23              Michigan                       2.34                      8.86
# 24            New Jersey                       2.34                      8.86
# 25                 Texas                       2.34                      8.86
# 26          Pennsylvania                       2.36                      8.93
# 27                  Iowa                       2.40                      9.08
# 28           Connecticut                       2.45                      9.27
# 29              Missouri                       2.49                      9.43
# 30         Massachusetts                       2.57                      9.73
# 31          Rhode Island                       2.57                      9.73
# 32             Louisiana                       2.59                      9.80
# 33                Hawaii                       2.63                      9.96
# 34               Florida                       2.65                     10.03
# 35               Wyoming                       2.67                     10.11
# 36                Oregon                       2.75                     10.41
# 37             Minnesota                       2.77                     10.49
# 38              Colorado                       2.81                     10.64
# 39                 Maine                       2.81                     10.64
# 40          South Dakota                       2.87                     10.86
# 41                 Idaho                       2.92                     11.05
# 42                Alaska                       2.94                     11.13
# 43             Wisconsin                       2.98                     11.28
# 44               Vermont                       3.08                     11.66
# 45               Montana                       3.11                     11.77
# 46          North Dakota                       3.26                     12.34
# 47                Nevada                       3.46                     13.10
# 48              Delaware                       3.72                     14.08
# 49  District of Columbia                       3.85                     14.57
# 50         New Hampshire                       4.76                     18.02
#
#          Pop
# 0    3221610
# 1    1791951
# 2    3026412
# 3    3948950
# 4    2910931
# 5   10627767
# 6    4484047
# 7    4898246
# 8   11718568
# 9   10497741
# 10   6833793
# 11   8571946
# 12   6062917
# 13   6718616
# 14  19491339
# 15   5147111
# 16   2987895
# 17   1940919
# 18   7666343
# 19   2096034
# 20   7275070
# 21  12700381
# 22  39747267
# 23  10020472
# 24   8922547
# 25  29087070
# 26  12813969
# 27   3167997
# 28   3567871
# 29   6147861
# 30   6939373
# 31   1056738
# 32   4652581
# 33   1416589
# 34  21646155
# 35    572381
# 36   4245901
# 37   5655925
# 38   5770545
# 39   1342097
# 40    892631
# 41   1790182
# 42    735720
# 43   5832661
# 44    627180
# 45   1074532
# 46    760900
# 47   3087025
# 48    975033
# 49    711571
# 50   1363852

# %%
alcohol_pd = alcohol_pd.sort_values(by = 'State')
alcohol_pd = alcohol_pd.reset_index(drop = True)
alcohol_pd
# Out:
#                    State  alcoholConsumptionGallons  alcoholConsumptionLiters  \
# 0                Alabama                       2.01                      7.61
# 1                 Alaska                       2.94                     11.13
# 2                Arizona                       2.31                      8.74
# 3               Arkansas                       1.80                      6.81
# 4             California                       2.33                      8.82
# 5               Colorado                       2.81                     10.64
# 6            Connecticut                       2.45                      9.27
# 7               Delaware                       3.72                     14.08
# 8   District of Columbia                       3.85                     14.57
# 9                Florida                       2.65                     10.03
# 10               Georgia                       1.94                      7.34
# 11                Hawaii                       2.63                      9.96
# 12                 Idaho                       2.92                     11.05
# 13              Illinois                       2.32                      8.78
# 14               Indiana                       2.17                      8.21
# 15                  Iowa                       2.40                      9.08
# 16                Kansas                       1.92                      7.27
# 17              Kentucky                       1.98                      7.50
# 18             Louisiana                       2.59                      9.80
# 19                 Maine                       2.81                     10.64
# 20              Maryland                       2.15                      8.14
# 21         Massachusetts                       2.57                      9.73
# 22              Michigan                       2.34                      8.86
# 23             Minnesota                       2.77                     10.49
# 24           Mississippi                       2.23                      8.44
# 25              Missouri                       2.49                      9.43
# 26               Montana                       3.11                     11.77
# 27              Nebraska                       2.23                      8.44
# 28                Nevada                       3.46                     13.10
# 29         New Hampshire                       4.76                     18.02
# 30            New Jersey                       2.34                      8.86
# 31            New Mexico                       2.27                      8.59
# 32              New York                       2.22                      8.40
# 33        North Carolina                       2.13                      8.06
# 34          North Dakota                       3.26                     12.34
# 35                  Ohio                       2.04                      7.72
# 36              Oklahoma                       1.88                      7.12
# 37                Oregon                       2.75                     10.41
# 38          Pennsylvania                       2.36                      8.93
# 39          Rhode Island                       2.57                      9.73
# 40        South Carolina                       2.22                      8.40
# 41          South Dakota                       2.87                     10.86
# 42             Tennessee                       2.14                      8.10
# 43                 Texas                       2.34                      8.86
# 44                  Utah                       1.34                      5.07
# 45               Vermont                       3.08                     11.66
# 46              Virginia                       2.14                      8.10
# 47            Washington                       2.26                      8.56
# 48         West Virginia                       1.76                      6.66
# 49             Wisconsin                       2.98                     11.28
# 50               Wyoming                       2.67                     10.11
#
#          Pop
# 0    4898246
# 1     735720
# 2    7275070
# 3    3026412
# 4   39747267
# 5    5770545
# 6    3567871
# 7     975033
# 8     711571
# 9   21646155
# 10  10627767
# 11   1416589
# 12   1790182
# 13  12700381
# 14   6718616
# 15   3167997
# 16   2910931
# 17   4484047
# 18   4652581
# 19   1342097
# 20   6062917
# 21   6939373
# 22  10020472
# 23   5655925
# 24   2987895
# 25   6147861
# 26   1074532
# 27   1940919
# 28   3087025
# 29   1363852
# 30   8922547
# 31   2096034
# 32  19491339
# 33  10497741
# 34    760900
# 35  11718568
# 36   3948950
# 37   4245901
# 38  12813969
# 39   1056738
# 40   5147111
# 41    892631
# 42   6833793
# 43  29087070
# 44   3221610
# 45    627180
# 46   8571946
# 47   7666343
# 48   1791951
# 49   5832661
# 50    572381

# %%
alcohol_pd.shape
# Out:
# (51, 4)

# %%
merged_table = pd.merge(life_expectancy_pd, alcohol_pd, how='outer', indicator=True)
merged_table
# table data seems to be cleaned now, ready for analysis
# Maine and Wisconsin have no data for life expectancy, we can choose to ignore them or impute the mean/median
# Out:
#                    State  Longevity  alcoholConsumptionGallons  \
# 0                Alabama       75.5                       2.01
# 1                 Alaska       78.8                       2.94
# 2                Arizona       79.9                       2.31
# 3               Arkansas       76.0                       1.80
# 4             California       81.3                       2.33
# 5               Colorado       80.5                       2.81
# 6            Connecticut       80.9                       2.45
# 7               Delaware       78.7                       3.72
# 8   District of Columbia       78.5                       3.85
# 9                Florida       80.1                       2.65
# 10               Georgia       77.7                       1.94
# 11                Hawaii       82.0                       2.63
# 12                 Idaho       79.4                       2.92
# 13              Illinois       79.3                       2.32
# 14               Indiana       77.4                       2.17
# 15                  Iowa       79.6                       2.40
# 16                Kansas       78.6                       1.92
# 17              Kentucky       75.9                       1.98
# 18             Louisiana       76.0                       2.59
# 19                 Maine        NaN                       2.81
# 20              Maryland       79.6                       2.15
# 21         Massachusetts       80.7                       2.57
# 22              Michigan       78.2                       2.34
# 23             Minnesota       81.0                       2.77
# 24           Mississippi       74.9                       2.23
# 25              Missouri       77.6                       2.49
# 26               Montana       78.6                       3.11
# 27              Nebraska       79.6                       2.23
# 28                Nevada       78.4                       3.46
# 29         New Hampshire       80.1                       4.76
# 30            New Jersey       80.5                       2.34
# 31            New Mexico       78.4                       2.27
# 32              New York       81.0                       2.22
# 33        North Carolina       78.1                       2.13
# 34          North Dakota       79.7                       3.26
# 35                  Ohio       77.6                       2.04
# 36              Oklahoma       75.8                       1.88
# 37                Oregon       79.6                       2.75
# 38          Pennsylvania       78.6                       2.36
# 39          Rhode Island       79.9                       2.57
# 40        South Carolina       77.0                       2.22
# 41          South Dakota       79.4                       2.87
# 42             Tennessee       76.3                       2.14
# 43                 Texas       78.8                       2.34
# 44                  Utah       79.8                       1.34
# 45               Vermont       80.0                       3.08
# 46              Virginia       79.4                       2.14
# 47            Washington       80.3                       2.26
# 48         West Virginia       75.3                       1.76
# 49             Wisconsin        NaN                       2.98
# 50               Wyoming       78.8                       2.67
#
#     alcoholConsumptionLiters       Pop _merge
# 0                       7.61   4898246   both
# 1                      11.13    735720   both
# 2                       8.74   7275070   both
# 3                       6.81   3026412   both
# 4                       8.82  39747267   both
# 5                      10.64   5770545   both
# 6                       9.27   3567871   both
# 7                      14.08    975033   both
# 8                      14.57    711571   both
# 9                      10.03  21646155   both
# 10                      7.34  10627767   both
# 11                      9.96   1416589   both
# 12                     11.05   1790182   both
# 13                      8.78  12700381   both
# 14                      8.21   6718616   both
# 15                      9.08   3167997   both
# 16                      7.27   2910931   both
# 17                      7.50   4484047   both
# 18                      9.80   4652581   both
# 19                     10.64   1342097   both
# 20                      8.14   6062917   both
# 21                      9.73   6939373   both
# 22                      8.86  10020472   both
# 23                     10.49   5655925   both
# 24                      8.44   2987895   both
# 25                      9.43   6147861   both
# 26                     11.77   1074532   both
# 27                      8.44   1940919   both
# 28                     13.10   3087025   both
# 29                     18.02   1363852   both
# 30                      8.86   8922547   both
# 31                      8.59   2096034   both
# 32                      8.40  19491339   both
# 33                      8.06  10497741   both
# 34                     12.34    760900   both
# 35                      7.72  11718568   both
# 36                      7.12   3948950   both
# 37                     10.41   4245901   both
# 38                      8.93  12813969   both
# 39                      9.73   1056738   both
# 40                      8.40   5147111   both
# 41                     10.86    892631   both
# 42                      8.10   6833793   both
# 43                      8.86  29087070   both
# 44                      5.07   3221610   both
# 45                     11.66    627180   both
# 46                      8.10   8571946   both
# 47                      8.56   7666343   both
# 48                      6.66   1791951   both
# 49                     11.28   5832661   both
# 50                     10.11    572381   both

# %%
merged_table = merged_table.dropna() # drop rows with NaN values
merged_table.shape
# Out:
# (49, 6)

# %%
def scatterPlotAndLine(x, y, title, y_label, x_label): # defining a function to allow code re-use
    stats = linregress(x, y)

    m = stats.slope
    b = stats.intercept

    plt.scatter(x, y)
    plt.plot(x, m * x + b, color="red")
    
    plt.title(title)
    plt.ylabel(y_label)
    plt.xlabel(x_label)
    
scatterPlotAndLine(x=merged_table.Longevity, y=merged_table.alcoholConsumptionGallons, 
                   title="Alcohol and Life Expectancy by State", y_label="Alcohol Consumption (gallons)", 
                   x_label="Life Expectancy at Birth (years)")

# %%
def computeModelSummary(x, y):
    # Note the difference in argument order
    model = sm.OLS(y, x).fit()
    predictions = model.predict(x) # make the predictions by the model

    # Print out the statistics
    return model.summary()

computeModelSummary(x=merged_table.Longevity, y=merged_table.alcoholConsumptionGallons)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                     OLS Regression Results
# ==============================================================================================
# Dep. Variable:     alcoholConsumptionGallons   R-squared (uncentered):                   0.951
# Model:                                   OLS   Adj. R-squared (uncentered):              0.950
# Method:                        Least Squares   F-statistic:                              922.6
# Date:                       Fri, 10 Jan 2020   Prob (F-statistic):                    5.38e-33
# Time:                               15:35:49   Log-Likelihood:                         -42.070
# No. Observations:                         49   AIC:                                      86.14
# Df Residuals:                             48   BIC:                                      88.03
# Df Model:                                  1
# Covariance Type:                   nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Longevity      0.0318      0.001     30.374      0.000       0.030       0.034
# ==============================================================================
# Omnibus:                       24.810   Durbin-Watson:                   1.736
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               44.723
# Skew:                           1.527   Prob(JB):                     1.94e-10
# Kurtosis:                       6.547   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
obesity = "./obesity_by_state.csv"

# %%
obesity = pd.read_csv(obesity)
obesity.head(10)
# Out:
#             State  obesityRank  obesityPercentage      Pop
# 0   West Virginia            1              0.381  1791951
# 1     Mississippi            2              0.373  2987895
# 2        Oklahoma            3              0.365  3948950
# 3            Iowa            4              0.364  3167997
# 4         Alabama            5              0.363  4898246
# 5       Louisiana            6              0.362  4652581
# 6        Arkansas            7              0.350  3026412
# 7        Kentucky            8              0.343  4484047
# 8          Alaska            9              0.342   735720
# 9  South Carolina           10              0.341  5147111

# %%
obesity = obesity.sort_values(by = 'State')
obesity = obesity.drop(['obesityRank', 'Pop'], axis = 1)
obesity.head()
# Out:
#          State  obesityPercentage
# 4      Alabama              0.363
# 8       Alaska              0.342
# 29     Arizona              0.295
# 6     Arkansas              0.350
# 47  California              0.251

# %%
obesity.shape
# Out:
# (50, 2)

# %%
merged_obesity_table = pd.merge(life_expectancy_pd, obesity, how='outer', indicator=True)
merged_obesity_table
# Out:
#                    State  Longevity  obesityPercentage     _merge
# 0                Alabama       75.5              0.363       both
# 1                 Alaska       78.8              0.342       both
# 2                Arizona       79.9              0.295       both
# 3               Arkansas       76.0              0.350       both
# 4             California       81.3              0.251       both
# 5               Colorado       80.5              0.226       both
# 6            Connecticut       80.9              0.269       both
# 7               Delaware       78.7              0.318       both
# 8   District of Columbia       78.5                NaN  left_only
# 9                Florida       80.1              0.284       both
# 10               Georgia       77.7              0.316       both
# 11                Hawaii       82.0              0.238       both
# 12                 Idaho       79.4              0.293       both
# 13              Illinois       79.3              0.311       both
# 14               Indiana       77.4              0.336       both
# 15                  Iowa       79.6              0.364       both
# 16                Kansas       78.6              0.324       both
# 17              Kentucky       75.9              0.343       both
# 18             Louisiana       76.0              0.362       both
# 19                 Maine        NaN              0.291       both
# 20              Maryland       79.6              0.313       both
# 21         Massachusetts       80.7              0.259       both
# 22              Michigan       78.2              0.323       both
# 23             Minnesota       81.0              0.284       both
# 24           Mississippi       74.9              0.373       both
# 25              Missouri       77.6              0.325       both
# 26               Montana       78.6              0.253       both
# 27              Nebraska       79.6              0.328       both
# 28                Nevada       78.4              0.267       both
# 29         New Hampshire       80.1              0.281       both
# 30            New Jersey       80.5              0.273       both
# 31            New Mexico       78.4              0.284       both
# 32              New York       81.0              0.257       both
# 33        North Carolina       78.1              0.321       both
# 34          North Dakota       79.7              0.332       both
# 35                  Ohio       77.6              0.338       both
# 36              Oklahoma       75.8              0.365       both
# 37                Oregon       79.6              0.294       both
# 38          Pennsylvania       78.6              0.316       both
# 39          Rhode Island       79.9              0.300       both
# 40        South Carolina       77.0              0.341       both
# 41          South Dakota       79.4              0.319       both
# 42             Tennessee       76.3              0.328       both
# 43                 Texas       78.8              0.330       both
# 44                  Utah       79.8              0.253       both
# 45               Vermont       80.0              0.276       both
# 46              Virginia       79.4              0.301       both
# 47            Washington       80.3              0.277       both
# 48         West Virginia       75.3              0.381       both
# 49             Wisconsin        NaN              0.320       both
# 50               Wyoming       78.8              0.288       both

# %%
merged_obesity_table = merged_obesity_table.dropna() # drop rows with NaN values

# %%
scatterPlotAndLine(x=merged_obesity_table.Longevity, y=merged_obesity_table.obesityPercentage, 
                   title="Obesity and Life Expectancy by State", y_label="Obesity Percentage", 
                   x_label="Life Expectancy at Birth (years)")

# %%
computeModelSummary(x=merged_obesity_table.Longevity, y=merged_obesity_table.obesityPercentage)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:      obesityPercentage   R-squared (uncentered):                   0.981
# Model:                            OLS   Adj. R-squared (uncentered):              0.980
# Method:                 Least Squares   F-statistic:                              2373.
# Date:                Fri, 10 Jan 2020   Prob (F-statistic):                    6.97e-42
# Time:                        16:01:26   Log-Likelihood:                          82.715
# No. Observations:                  48   AIC:                                     -163.4
# Df Residuals:                      47   BIC:                                     -161.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Longevity      0.0039      8e-05     48.711      0.000       0.004       0.004
# ==============================================================================
# Omnibus:                        1.590   Durbin-Watson:                   1.692
# Prob(Omnibus):                  0.452   Jarque-Bera (JB):                1.112
# Skew:                           0.006   Prob(JB):                        0.574
# Kurtosis:                       2.255   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
cigarette = "./current_cigarette_use.csv" #renamed cigarette file

# %%
cigarette_pd = pd.read_csv(cigarette)
cigarette_pd.head()
# Out:
#   Location Desc  Data Value  Low Confidence Limit  High Confidence Limit  \
# 0       Alabama        20.9                  19.5                   22.3
# 1        Alaska        21.0                  18.3                   23.7
# 2       Arizona        15.6                  14.8                   16.4
# 3      Arkansas        22.3                  20.0                   24.6
# 4    California        11.3                  10.3                   12.3
#
#   Sample Size   $$hashKey $$stateabbreviation $$statename  $$stateId  \
# 0       6,472  object:188                  al     Alabama          1
# 1       3,084  object:189                  ak      Alaska          2
# 2      14,770  object:190                  az     Arizona          4
# 3       5,100  object:191                  ar    Arkansas          5
# 4       8,717  object:192                  ca  California          6
#
#    timeIntervalDataVal        $$color  textoffsety type  textoffsetx
# 0                    0  class5_color4          NaN  NaN          NaN
# 1                    0  class5_color4          NaN  NaN          NaN
# 2                    0  class5_color2          NaN  NaN          NaN
# 3                    0  class5_color4          3.0  NaN          NaN
# 4                    0  class5_color1         10.0  NaN          NaN

# %%
#rename columns
cigarette_pd.rename(columns = {'Location Desc':'State', 'Data Value':'cigarettePercent'}, inplace = True)

# %%
#sort and remove extra columns
cigarette_pd = cigarette_pd.sort_values(by = 'State')
cigarette_pd = cigarette_pd.drop(['Low Confidence Limit', 'High Confidence Limit', 'Sample Size', '$$hashKey', 
                                  '$$stateabbreviation','$$statename', '$$stateId', 'timeIntervalDataVal',
                                 '$$color', 'textoffsety', 'type', 'textoffsetx' ], axis = 1)
print(cigarette_pd)
# Out:
#                    State  cigarettePercent
# 0                Alabama              20.9
# 1                 Alaska              21.0
# 2                Arizona              15.6
# 3               Arkansas              22.3
# 4             California              11.3
# 5               Colorado              14.6
# 6            Connecticut              12.7
# 7               Delaware              17.0
# 8   District of Columbia              14.3
# 9                Florida              16.1
# 10               Georgia              17.5
# 11                  Guam              26.4
# 12                Hawaii              12.8
# 13                 Idaho              14.3
# 14              Illinois              15.5
# 15               Indiana              21.8
# 16                  Iowa              17.1
# 17                Kansas              17.4
# 18              Kentucky              24.6
# 19             Louisiana              23.1
# 20                 Maine              17.3
# 21              Maryland              13.8
# 22         Massachusetts              13.7
# 23              Michigan              19.3
# 24             Minnesota              14.5
# 25           Mississippi              22.2
# 26              Missouri              20.8
# 27               Montana              17.2
# 28              Nebraska              15.4
# 29                Nevada              17.6
# 30         New Hampshire              15.7
# 31            New Jersey              13.7
# 32            New Mexico              17.5
# 33              New York              14.1
# 34        North Carolina              17.2
# 35          North Dakota              18.3
# 36                  Ohio              21.1
# 37              Oklahoma              20.1
# 38                Oregon              16.1
# 39          Pennsylvania              18.7
# 40           Puerto Rico              11.3
# 41          Rhode Island              14.9
# 42        South Carolina              18.8
# 43          South Dakota              19.3
# 44             Tennessee              22.6
# 45                 Texas              15.7
# 46                  Utah               8.9
# 47               Vermont              15.8
# 48              Virginia              16.4
# 49            Washington              13.5
# 50         West Virginia              26.0
# 51             Wisconsin              16.0
# 52               Wyoming              18.7

# %%
cigarette_pd.shape
# Out:
# (53, 2)

# %%
merged_cigarette_table = pd.merge(life_expectancy_pd, cigarette_pd, how='outer', on='State', indicator=True)
merged_cigarette_table
# Out:
#                    State  Longevity  cigarettePercent      _merge
# 0                Alabama       75.5              20.9        both
# 1                 Alaska       78.8              21.0        both
# 2                Arizona       79.9              15.6        both
# 3               Arkansas       76.0              22.3        both
# 4             California       81.3              11.3        both
# 5               Colorado       80.5              14.6        both
# 6            Connecticut       80.9              12.7        both
# 7               Delaware       78.7              17.0        both
# 8   District of Columbia       78.5              14.3        both
# 9                Florida       80.1              16.1        both
# 10               Georgia       77.7              17.5        both
# 11                Hawaii       82.0              12.8        both
# 12                 Idaho       79.4              14.3        both
# 13              Illinois       79.3              15.5        both
# 14               Indiana       77.4              21.8        both
# 15                  Iowa       79.6              17.1        both
# 16                Kansas       78.6              17.4        both
# 17              Kentucky       75.9              24.6        both
# 18             Louisiana       76.0              23.1        both
# 19                 Maine        NaN              17.3        both
# 20              Maryland       79.6              13.8        both
# 21         Massachusetts       80.7              13.7        both
# 22              Michigan       78.2              19.3        both
# 23             Minnesota       81.0              14.5        both
# 24           Mississippi       74.9              22.2        both
# 25              Missouri       77.6              20.8        both
# 26               Montana       78.6              17.2        both
# 27              Nebraska       79.6              15.4        both
# 28                Nevada       78.4              17.6        both
# 29         New Hampshire       80.1              15.7        both
# 30            New Jersey       80.5              13.7        both
# 31            New Mexico       78.4              17.5        both
# 32              New York       81.0              14.1        both
# 33        North Carolina       78.1              17.2        both
# 34          North Dakota       79.7              18.3        both
# 35                  Ohio       77.6              21.1        both
# 36              Oklahoma       75.8              20.1        both
# 37                Oregon       79.6              16.1        both
# 38          Pennsylvania       78.6              18.7        both
# 39          Rhode Island       79.9              14.9        both
# 40        South Carolina       77.0              18.8        both
# 41          South Dakota       79.4              19.3        both
# 42             Tennessee       76.3              22.6        both
# 43                 Texas       78.8              15.7        both
# 44                  Utah       79.8               8.9        both
# 45               Vermont       80.0              15.8        both
# 46              Virginia       79.4              16.4        both
# 47            Washington       80.3              13.5        both
# 48         West Virginia       75.3              26.0        both
# 49             Wisconsin        NaN              16.0        both
# 50               Wyoming       78.8              18.7        both
# 51                  Guam        NaN              26.4  right_only
# 52           Puerto Rico        NaN              11.3  right_only

# %%
merged_cigarette_table = merged_cigarette_table.dropna() # drop rows with NaN values
merged_cigarette_table
# Out:
#                    State  Longevity  cigarettePercent _merge
# 0                Alabama       75.5              20.9   both
# 1                 Alaska       78.8              21.0   both
# 2                Arizona       79.9              15.6   both
# 3               Arkansas       76.0              22.3   both
# 4             California       81.3              11.3   both
# 5               Colorado       80.5              14.6   both
# 6            Connecticut       80.9              12.7   both
# 7               Delaware       78.7              17.0   both
# 8   District of Columbia       78.5              14.3   both
# 9                Florida       80.1              16.1   both
# 10               Georgia       77.7              17.5   both
# 11                Hawaii       82.0              12.8   both
# 12                 Idaho       79.4              14.3   both
# 13              Illinois       79.3              15.5   both
# 14               Indiana       77.4              21.8   both
# 15                  Iowa       79.6              17.1   both
# 16                Kansas       78.6              17.4   both
# 17              Kentucky       75.9              24.6   both
# 18             Louisiana       76.0              23.1   both
# 20              Maryland       79.6              13.8   both
# 21         Massachusetts       80.7              13.7   both
# 22              Michigan       78.2              19.3   both
# 23             Minnesota       81.0              14.5   both
# 24           Mississippi       74.9              22.2   both
# 25              Missouri       77.6              20.8   both
# 26               Montana       78.6              17.2   both
# 27              Nebraska       79.6              15.4   both
# 28                Nevada       78.4              17.6   both
# 29         New Hampshire       80.1              15.7   both
# 30            New Jersey       80.5              13.7   both
# 31            New Mexico       78.4              17.5   both
# 32              New York       81.0              14.1   both
# 33        North Carolina       78.1              17.2   both
# 34          North Dakota       79.7              18.3   both
# 35                  Ohio       77.6              21.1   both
# 36              Oklahoma       75.8              20.1   both
# 37                Oregon       79.6              16.1   both
# 38          Pennsylvania       78.6              18.7   both
# 39          Rhode Island       79.9              14.9   both
# 40        South Carolina       77.0              18.8   both
# 41          South Dakota       79.4              19.3   both
# 42             Tennessee       76.3              22.6   both
# 43                 Texas       78.8              15.7   both
# 44                  Utah       79.8               8.9   both
# 45               Vermont       80.0              15.8   both
# 46              Virginia       79.4              16.4   both
# 47            Washington       80.3              13.5   both
# 48         West Virginia       75.3              26.0   both
# 50               Wyoming       78.8              18.7   both

# %%
merged_cigarette_table.shape #check number of rows and columns
# Out:
# (49, 4)

# %%
scatterPlotAndLine(x=merged_cigarette_table.Longevity, y=merged_cigarette_table.cigarettePercent, 
                   title="Cigarette Consumption and Life Expectancy by State", y_label="Cigarette Consumption Percentage", 
                   x_label="Life Expectancy at Birth (years)")

# %%
computeModelSummary(x=merged_cigarette_table.Longevity, y=merged_cigarette_table.cigarettePercent)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:       cigarettePercent   R-squared (uncentered):                   0.952
# Model:                            OLS   Adj. R-squared (uncentered):              0.952
# Method:                 Least Squares   F-statistic:                              962.4
# Date:                Fri, 10 Jan 2020   Prob (F-statistic):                    2.05e-33
# Time:                        16:03:43   Log-Likelihood:                         -135.55
# No. Observations:                  49   AIC:                                      273.1
# Df Residuals:                      48   BIC:                                      275.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Longevity      0.2187      0.007     31.023      0.000       0.205       0.233
# ==============================================================================
# Omnibus:                        1.097   Durbin-Watson:                   1.801
# Prob(Omnibus):                  0.578   Jarque-Bera (JB):                1.073
# Skew:                           0.332   Prob(JB):                        0.585
# Kurtosis:                       2.711   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
nutrition = "./nutrition.csv"
nutrition = pd.read_csv(nutrition)
nutrition.head()
# Out:
#    YearStart  YearEnd LocationAbbr          LocationDesc  \
# 0       2012     2012           WY               Wyoming
# 1       2012     2012           DC  District of Columbia
# 2       2011     2011           AL               Alabama
# 3       2013     2013           US              National
# 4       2011     2011           US              National
#
#                                    Datasource                    Class  \
# 0  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3  Behavioral Risk Factor Surveillance System        Physical Activity
# 4  Behavioral Risk Factor Surveillance System        Physical Activity
#
#                           Topic  \
# 0       Obesity / Weight Status
# 1       Obesity / Weight Status
# 2       Obesity / Weight Status
# 3  Physical Activity - Behavior
# 4  Physical Activity - Behavior
#
#                                             Question  Data_Value_Unit  \
# 0  Percent of adults aged 18 years and older who ...              NaN
# 1  Percent of adults aged 18 years and older who ...              NaN
# 2  Percent of adults aged 18 years and older who ...              NaN
# 3  Percent of adults who engage in no leisure-tim...              NaN
# 4  Percent of adults who engage in no leisure-tim...              NaN
#
#   Data_Value_Type  ...                     GeoLocation  ClassID TopicID  \
# 0           Value  ...  (43.235541343, -108.109830353)      OWS    OWS1
# 1           Value  ...   (38.890371385, -77.031961127)      OWS    OWS1
# 2           Value  ...   (32.840571122, -86.631860762)      OWS    OWS1
# 3           Value  ...                             NaN       PA     PA1
# 4           Value  ...                             NaN       PA     PA1
#
#   QuestionID  DataValueTypeID  LocationID  StratificationCategory1  \
# 0       Q037            VALUE          56           Race/Ethnicity
# 1       Q036            VALUE          11                Education
# 2       Q036            VALUE           1              Age (years)
# 3       Q047            VALUE          59                   Gender
# 4       Q047            VALUE          59              Age (years)
#
#                  Stratification1 StratificationCategoryId1 StratificationID1
# 0  American Indian/Alaska Native                      RACE           RACENAA
# 1          Less than high school                       EDU             EDUHS
# 2                        25 - 34                     AGEYR         AGEYR2534
# 3                         Female                       GEN            FEMALE
# 4                        18 - 24                     AGEYR         AGEYR1824
#
# [5 rows x 33 columns]

# %%
nutrition.columns # see what columns the table has
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'Datasource',
#        'Class', 'Topic', 'Question', 'Data_Value_Unit', 'Data_Value_Type',
#        'Data_Value', 'Data_Value_Alt', 'Data_Value_Footnote_Symbol',
#        'Data_Value_Footnote', 'Low_Confidence_Limit', 'High_Confidence_Limit ',
#        'Sample_Size', 'Total', 'Age(years)', 'Education', 'Gender', 'Income',
#        'Race/Ethnicity', 'GeoLocation', 'ClassID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'LocationID', 'StratificationCategory1',
#        'Stratification1', 'StratificationCategoryId1', 'StratificationID1'],
#       dtype='object')

# %%
# remove columns we don't need
nutrition = nutrition.drop(columns=['LocationAbbr', 'Total', 'StratificationID1',
                           'Datasource', 'Topic', 'Data_Value_Unit', 'Data_Value_Type',
                           'Data_Value_Alt', 'Data_Value_Footnote_Symbol', 
                           'Data_Value_Footnote', 'Low_Confidence_Limit',
                           'Age(years)', 'Education', 'Gender', 'Income',
                           'Race/Ethnicity', 'GeoLocation', 'ClassID', 'TopicID',
                           'QuestionID', 'DataValueTypeID', 'LocationID',
                           'StratificationCategory1', 'Stratification1',
                           'StratificationCategoryId1', 'High_Confidence_Limit ', 'YearStart'])
nutrition.head()
# Out:
#    YearEnd          LocationDesc                    Class  \
# 0     2012               Wyoming  Obesity / Weight Status
# 1     2012  District of Columbia  Obesity / Weight Status
# 2     2011               Alabama  Obesity / Weight Status
# 3     2013              National        Physical Activity
# 4     2011              National        Physical Activity
#
#                                             Question  Data_Value  Sample_Size
# 0  Percent of adults aged 18 years and older who ...        48.5         69.0
# 1  Percent of adults aged 18 years and older who ...        31.6        243.0
# 2  Percent of adults aged 18 years and older who ...        35.2        598.0
# 3  Percent of adults who engage in no leisure-tim...        27.9     266452.0
# 4  Percent of adults who engage in no leisure-tim...        16.9      20923.0

# %%
print(nutrition.LocationDesc.unique()) # see locations to remove non-states
nutrition = nutrition[nutrition.LocationDesc != 'US']
nutrition = nutrition[nutrition.LocationDesc != 'Guam']
nutrition = nutrition[nutrition.LocationDesc != 'Puerto Rico']
nutrition = nutrition[nutrition.LocationDesc != 'Virgin Islands']
nutrition = nutrition[nutrition.LocationDesc != 'National']
len(nutrition.LocationDesc.unique())
# Out:
# ['Wyoming' 'District of Columbia' 'Alabama' 'National' 'Rhode Island'
#  'Minnesota' 'Washington' 'Georgia' 'Wisconsin' 'Delaware' 'New Jersey'
#  'North Carolina' 'Pennsylvania' 'Oklahoma' 'Michigan' 'Vermont'
#  'Massachusetts' 'California' 'Utah' 'North Dakota' 'Tennessee' 'Colorado'
#  'New York' 'Florida' 'Montana' 'Kansas' 'New Hampshire' 'Virginia'
#  'Louisiana' 'Oregon' 'Maine' 'Alaska' 'Iowa' 'Indiana' 'South Dakota'
#  'Connecticut' 'Guam' 'Illinois' 'Maryland' 'Hawaii' 'New Mexico'
#  'Arizona' 'Arkansas' 'West Virginia' 'Mississippi' 'Missouri' 'Nebraska'
#  'Texas' 'South Carolina' 'Kentucky' 'Nevada' 'Ohio' 'Idaho' 'Puerto Rico'
#  'Virgin Islands']
# 51

# %%
nutrition = nutrition.dropna() # drop NaN values

# %%
nutrition.Class.unique() # see unique classes
# Out:
# array(['Obesity / Weight Status', 'Physical Activity',
#        'Fruits and Vegetables'], dtype=object)

# %%
nutrition_physical = nutrition[nutrition.Class == 'Physical Activity'] # isolate by 'Physical Activity' class
nutrition_physical.head()
# Out:
#     YearEnd LocationDesc              Class  \
# 8      2012      Wyoming  Physical Activity
# 9      2013    Minnesota  Physical Activity
# 12     2015    Wisconsin  Physical Activity
# 13     2011     Delaware  Physical Activity
# 14     2015   New Jersey  Physical Activity
#
#                                              Question  Data_Value  Sample_Size
# 8   Percent of adults who engage in no leisure-tim...        32.3        484.0
# 9   Percent of adults who achieve at least 150 min...        52.8       3680.0
# 12  Percent of adults who achieve at least 150 min...        19.1        412.0
# 13  Percent of adults who engage in no leisure-tim...        24.4        707.0
# 14  Percent of adults who achieve at least 150 min...        37.6        566.0

# %%
print(nutrition_physical.YearEnd.unique()) # print list of years
nutrition_physical = nutrition_physical[nutrition_physical.YearEnd == 2018] # only consider latest year (2018)
# Out:
# [2012 2013 2015 2011 2014 2016 2018 2017]

# %%
# Lets calculate a weighted average because the data_values for a state are for different sample sizes

# Weighted average function
def wavg(group, avg_name, weight_name):
    d = group[avg_name]
    w = group[weight_name]
    return (d * w).sum() / w.sum()


# Calculate weighted average for physical activity
physical_wa_by_state = nutrition_physical.groupby("LocationDesc").apply(wavg, "Data_Value", "Sample_Size")


# Convert series to dataframe
physical_wa_df = pd.DataFrame({'State':physical_wa_by_state.index, 'infrequentPhysicalActivityPercent':physical_wa_by_state.values})
physical_wa_df = physical_wa_df.round(2) # round to 2 decimal places
physical_wa_df
# Out:
#                    State  infrequentPhysicalActivityPercent
# 0                Alabama                              30.88
# 1                 Alaska                              19.67
# 2                Arizona                              22.33
# 3               Arkansas                              31.72
# 4             California                              20.78
# 5               Colorado                              16.34
# 6            Connecticut                              22.06
# 7               Delaware                              27.09
# 8   District of Columbia                              19.60
# 9                Florida                              26.74
# 10               Georgia                              26.20
# 11                Hawaii                              19.66
# 12                 Idaho                              20.43
# 13              Illinois                              24.47
# 14               Indiana                              27.89
# 15                  Iowa                              22.93
# 16                Kansas                              22.65
# 17              Kentucky                              32.87
# 18             Louisiana                              30.41
# 19                 Maine                              22.86
# 20              Maryland                              22.90
# 21         Massachusetts                              22.06
# 22              Michigan                              23.62
# 23             Minnesota                              20.40
# 24           Mississippi                              32.57
# 25              Missouri                              26.66
# 26               Montana                              23.11
# 27              Nebraska                              24.17
# 28                Nevada                              24.61
# 29         New Hampshire                              21.62
# 30            New Jersey                              28.45
# 31            New Mexico                              22.22
# 32              New York                              23.74
# 33        North Carolina                              23.98
# 34          North Dakota                              22.77
# 35                  Ohio                              25.89
# 36              Oklahoma                              27.47
# 37                Oregon                              19.12
# 38          Pennsylvania                              23.63
# 39          Rhode Island                              25.09
# 40        South Carolina                              27.12
# 41          South Dakota                              24.39
# 42             Tennessee                              30.93
# 43                 Texas                              25.43
# 44                  Utah                              17.37
# 45               Vermont                              19.03
# 46              Virginia                              22.16
# 47            Washington                              17.60
# 48         West Virginia                              28.44
# 49             Wisconsin                              21.90
# 50               Wyoming                              22.01

# %%
# Convert the inverted percent (people who don't exercise frequently) to the regular percent (people who do exercise frequently)
physical_wa_df.rename(columns = {'infrequentPhysicalActivityPercent':'physicalActivityPercent'}, inplace = True)
physical_wa_df['physicalActivityPercent'] = physical_wa_df['physicalActivityPercent'].map(lambda x: 100-x)
physical_wa_df
# Out:
#                    State  physicalActivityPercent
# 0                Alabama                    69.12
# 1                 Alaska                    80.33
# 2                Arizona                    77.67
# 3               Arkansas                    68.28
# 4             California                    79.22
# 5               Colorado                    83.66
# 6            Connecticut                    77.94
# 7               Delaware                    72.91
# 8   District of Columbia                    80.40
# 9                Florida                    73.26
# 10               Georgia                    73.80
# 11                Hawaii                    80.34
# 12                 Idaho                    79.57
# 13              Illinois                    75.53
# 14               Indiana                    72.11
# 15                  Iowa                    77.07
# 16                Kansas                    77.35
# 17              Kentucky                    67.13
# 18             Louisiana                    69.59
# 19                 Maine                    77.14
# 20              Maryland                    77.10
# 21         Massachusetts                    77.94
# 22              Michigan                    76.38
# 23             Minnesota                    79.60
# 24           Mississippi                    67.43
# 25              Missouri                    73.34
# 26               Montana                    76.89
# 27              Nebraska                    75.83
# 28                Nevada                    75.39
# 29         New Hampshire                    78.38
# 30            New Jersey                    71.55
# 31            New Mexico                    77.78
# 32              New York                    76.26
# 33        North Carolina                    76.02
# 34          North Dakota                    77.23
# 35                  Ohio                    74.11
# 36              Oklahoma                    72.53
# 37                Oregon                    80.88
# 38          Pennsylvania                    76.37
# 39          Rhode Island                    74.91
# 40        South Carolina                    72.88
# 41          South Dakota                    75.61
# 42             Tennessee                    69.07
# 43                 Texas                    74.57
# 44                  Utah                    82.63
# 45               Vermont                    80.97
# 46              Virginia                    77.84
# 47            Washington                    82.40
# 48         West Virginia                    71.56
# 49             Wisconsin                    78.10
# 50               Wyoming                    77.99

# %%
nutrition_fruits = nutrition[nutrition.Class == 'Fruits and Vegetables'] # isolate by 'Fruits and Vegetables' class
nutrition_fruits.head()
# Out:
#       YearEnd   LocationDesc                  Class  \
# 7054     2017          Maine  Fruits and Vegetables
# 7114     2017       Missouri  Fruits and Vegetables
# 7232     2017  Massachusetts  Fruits and Vegetables
# 7350     2017       Michigan  Fruits and Vegetables
# 7489     2017       Missouri  Fruits and Vegetables
#
#                                                Question  Data_Value  \
# 7054  Percent of adults who report consuming vegetab...        11.7
# 7114  Percent of adults who report consuming fruit l...        43.4
# 7232  Percent of adults who report consuming fruit l...        29.9
# 7350  Percent of adults who report consuming vegetab...        17.5
# 7489  Percent of adults who report consuming fruit l...        40.4
#
#       Sample_Size
# 7054       2280.0
# 7114       2986.0
# 7232        452.0
# 7350       1585.0
# 7489       5906.0

# %%
print(nutrition_fruits.YearEnd.unique()) # print list of years
nutrition_fruits = nutrition_fruits[nutrition_fruits.YearEnd == 2017] # only consider latest year (2017)
nutrition_fruits.head()
# Out:
# [2017]
#       YearEnd   LocationDesc                  Class  \
# 7054     2017          Maine  Fruits and Vegetables
# 7114     2017       Missouri  Fruits and Vegetables
# 7232     2017  Massachusetts  Fruits and Vegetables
# 7350     2017       Michigan  Fruits and Vegetables
# 7489     2017       Missouri  Fruits and Vegetables
#
#                                                Question  Data_Value  \
# 7054  Percent of adults who report consuming vegetab...        11.7
# 7114  Percent of adults who report consuming fruit l...        43.4
# 7232  Percent of adults who report consuming fruit l...        29.9
# 7350  Percent of adults who report consuming vegetab...        17.5
# 7489  Percent of adults who report consuming fruit l...        40.4
#
#       Sample_Size
# 7054       2280.0
# 7114       2986.0
# 7232        452.0
# 7350       1585.0
# 7489       5906.0

# %%
# Calculate weighted average for fruits and vegetables
fruits_wa_by_state = nutrition_fruits.groupby("LocationDesc").apply(wavg, "Data_Value", "Sample_Size")


# Convert series to dataframe
fruits_wa_df = pd.DataFrame({'State':fruits_wa_by_state.index, 'infrequentFruitsVegetablesConsumptionPercent':fruits_wa_by_state.values})
fruits_wa_df = fruits_wa_df.round(2) # round to 2 decimal places
fruits_wa_df
# Out:
#                    State  infrequentFruitsVegetablesConsumptionPercent
# 0                Alabama                                         32.02
# 1                 Alaska                                         27.54
# 2                Arizona                                         28.40
# 3               Arkansas                                         31.77
# 4             California                                         26.47
# 5               Colorado                                         24.72
# 6            Connecticut                                         23.57
# 7               Delaware                                         26.19
# 8   District of Columbia                                         22.42
# 9                Florida                                         26.69
# 10               Georgia                                         28.33
# 11                Hawaii                                         28.48
# 12                 Idaho                                         25.28
# 13              Illinois                                         26.78
# 14               Indiana                                         29.60
# 15                  Iowa                                         27.23
# 16                Kansas                                         27.17
# 17              Kentucky                                         29.90
# 18             Louisiana                                         34.01
# 19                 Maine                                         21.47
# 20              Maryland                                         25.72
# 21         Massachusetts                                         23.68
# 22              Michigan                                         27.00
# 23             Minnesota                                         24.80
# 24           Mississippi                                         33.44
# 25              Missouri                                         28.26
# 26               Montana                                         25.59
# 27              Nebraska                                         28.18
# 28                Nevada                                         29.21
# 29         New Hampshire                                         21.65
# 30            New Jersey                                         26.02
# 31            New Mexico                                         28.55
# 32              New York                                         26.52
# 33        North Carolina                                         26.44
# 34          North Dakota                                         28.01
# 35                  Ohio                                         27.99
# 36              Oklahoma                                         31.42
# 37                Oregon                                         24.18
# 38          Pennsylvania                                         24.94
# 39          Rhode Island                                         25.26
# 40        South Carolina                                         29.12
# 41          South Dakota                                         26.68
# 42             Tennessee                                         27.32
# 43                 Texas                                         30.27
# 44                  Utah                                         24.31
# 45               Vermont                                         21.05
# 46              Virginia                                         25.88
# 47            Washington                                         24.05
# 48         West Virginia                                         31.51
# 49             Wisconsin                                         25.38
# 50               Wyoming                                         26.13

# %%
# Convert the inverted percent (people who don't consume fruits frequently) to the regular percent (people who do consume fruits frequently)
fruits_wa_df.rename(columns = {'infrequentFruitsVegetablesConsumptionPercent':'fruitsVegetablesConsumptionPercent'}, inplace = True)
fruits_wa_df['fruitsVegetablesConsumptionPercent'] = fruits_wa_df['fruitsVegetablesConsumptionPercent'].map(lambda x: 100-x)
fruits_wa_df
# Out:
#                    State  fruitsVegetablesConsumptionPercent
# 0                Alabama                               67.98
# 1                 Alaska                               72.46
# 2                Arizona                               71.60
# 3               Arkansas                               68.23
# 4             California                               73.53
# 5               Colorado                               75.28
# 6            Connecticut                               76.43
# 7               Delaware                               73.81
# 8   District of Columbia                               77.58
# 9                Florida                               73.31
# 10               Georgia                               71.67
# 11                Hawaii                               71.52
# 12                 Idaho                               74.72
# 13              Illinois                               73.22
# 14               Indiana                               70.40
# 15                  Iowa                               72.77
# 16                Kansas                               72.83
# 17              Kentucky                               70.10
# 18             Louisiana                               65.99
# 19                 Maine                               78.53
# 20              Maryland                               74.28
# 21         Massachusetts                               76.32
# 22              Michigan                               73.00
# 23             Minnesota                               75.20
# 24           Mississippi                               66.56
# 25              Missouri                               71.74
# 26               Montana                               74.41
# 27              Nebraska                               71.82
# 28                Nevada                               70.79
# 29         New Hampshire                               78.35
# 30            New Jersey                               73.98
# 31            New Mexico                               71.45
# 32              New York                               73.48
# 33        North Carolina                               73.56
# 34          North Dakota                               71.99
# 35                  Ohio                               72.01
# 36              Oklahoma                               68.58
# 37                Oregon                               75.82
# 38          Pennsylvania                               75.06
# 39          Rhode Island                               74.74
# 40        South Carolina                               70.88
# 41          South Dakota                               73.32
# 42             Tennessee                               72.68
# 43                 Texas                               69.73
# 44                  Utah                               75.69
# 45               Vermont                               78.95
# 46              Virginia                               74.12
# 47            Washington                               75.95
# 48         West Virginia                               68.49
# 49             Wisconsin                               74.62
# 50               Wyoming                               73.87

# %%
merged_physical_table = pd.merge(life_expectancy_pd, physical_wa_df, how='outer', on='State', indicator=True)
merged_physical_table = merged_physical_table.dropna() # drop rows with NaN values
merged_physical_table
# Out:
#                    State  Longevity  physicalActivityPercent _merge
# 0                Alabama       75.5                    69.12   both
# 1                 Alaska       78.8                    80.33   both
# 2                Arizona       79.9                    77.67   both
# 3               Arkansas       76.0                    68.28   both
# 4             California       81.3                    79.22   both
# 5               Colorado       80.5                    83.66   both
# 6            Connecticut       80.9                    77.94   both
# 7               Delaware       78.7                    72.91   both
# 8   District of Columbia       78.5                    80.40   both
# 9                Florida       80.1                    73.26   both
# 10               Georgia       77.7                    73.80   both
# 11                Hawaii       82.0                    80.34   both
# 12                 Idaho       79.4                    79.57   both
# 13              Illinois       79.3                    75.53   both
# 14               Indiana       77.4                    72.11   both
# 15                  Iowa       79.6                    77.07   both
# 16                Kansas       78.6                    77.35   both
# 17              Kentucky       75.9                    67.13   both
# 18             Louisiana       76.0                    69.59   both
# 20              Maryland       79.6                    77.10   both
# 21         Massachusetts       80.7                    77.94   both
# 22              Michigan       78.2                    76.38   both
# 23             Minnesota       81.0                    79.60   both
# 24           Mississippi       74.9                    67.43   both
# 25              Missouri       77.6                    73.34   both
# 26               Montana       78.6                    76.89   both
# 27              Nebraska       79.6                    75.83   both
# 28                Nevada       78.4                    75.39   both
# 29         New Hampshire       80.1                    78.38   both
# 30            New Jersey       80.5                    71.55   both
# 31            New Mexico       78.4                    77.78   both
# 32              New York       81.0                    76.26   both
# 33        North Carolina       78.1                    76.02   both
# 34          North Dakota       79.7                    77.23   both
# 35                  Ohio       77.6                    74.11   both
# 36              Oklahoma       75.8                    72.53   both
# 37                Oregon       79.6                    80.88   both
# 38          Pennsylvania       78.6                    76.37   both
# 39          Rhode Island       79.9                    74.91   both
# 40        South Carolina       77.0                    72.88   both
# 41          South Dakota       79.4                    75.61   both
# 42             Tennessee       76.3                    69.07   both
# 43                 Texas       78.8                    74.57   both
# 44                  Utah       79.8                    82.63   both
# 45               Vermont       80.0                    80.97   both
# 46              Virginia       79.4                    77.84   both
# 47            Washington       80.3                    82.40   both
# 48         West Virginia       75.3                    71.56   both
# 50               Wyoming       78.8                    77.99   both

# %%
scatterPlotAndLine(x=merged_physical_table.Longevity, y=merged_physical_table.physicalActivityPercent, 
                   title="Physical Activity and Life Expectancy by State", y_label="Physical Activity Percentage", 
                   x_label="Life Expectancy at Birth (years)")

# %%
computeModelSummary(x=merged_physical_table.Longevity, y=merged_physical_table.physicalActivityPercent)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     physicalActivityPercent   R-squared (uncentered):                   0.999
# Model:                                 OLS   Adj. R-squared (uncentered):              0.998
# Method:                      Least Squares   F-statistic:                          3.245e+04
# Date:                     Fri, 10 Jan 2020   Prob (F-statistic):                    1.33e-69
# Time:                             16:11:04   Log-Likelihood:                         -122.02
# No. Observations:                       49   AIC:                                      246.0
# Df Residuals:                           48   BIC:                                      247.9
# Df Model:                                1
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Longevity      0.9635      0.005    180.151      0.000       0.953       0.974
# ==============================================================================
# Omnibus:                        0.030   Durbin-Watson:                   2.082
# Prob(Omnibus):                  0.985   Jarque-Bera (JB):                0.212
# Skew:                           0.005   Prob(JB):                        0.900
# Kurtosis:                       2.678   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
merged_fruits_table = pd.merge(life_expectancy_pd, fruits_wa_df, how='outer', on='State', indicator=True)
merged_fruits_table = merged_fruits_table.dropna() # drop rows with NaN values
merged_fruits_table
# Out:
#                    State  Longevity  fruitsVegetablesConsumptionPercent _merge
# 0                Alabama       75.5                               67.98   both
# 1                 Alaska       78.8                               72.46   both
# 2                Arizona       79.9                               71.60   both
# 3               Arkansas       76.0                               68.23   both
# 4             California       81.3                               73.53   both
# 5               Colorado       80.5                               75.28   both
# 6            Connecticut       80.9                               76.43   both
# 7               Delaware       78.7                               73.81   both
# 8   District of Columbia       78.5                               77.58   both
# 9                Florida       80.1                               73.31   both
# 10               Georgia       77.7                               71.67   both
# 11                Hawaii       82.0                               71.52   both
# 12                 Idaho       79.4                               74.72   both
# 13              Illinois       79.3                               73.22   both
# 14               Indiana       77.4                               70.40   both
# 15                  Iowa       79.6                               72.77   both
# 16                Kansas       78.6                               72.83   both
# 17              Kentucky       75.9                               70.10   both
# 18             Louisiana       76.0                               65.99   both
# 20              Maryland       79.6                               74.28   both
# 21         Massachusetts       80.7                               76.32   both
# 22              Michigan       78.2                               73.00   both
# 23             Minnesota       81.0                               75.20   both
# 24           Mississippi       74.9                               66.56   both
# 25              Missouri       77.6                               71.74   both
# 26               Montana       78.6                               74.41   both
# 27              Nebraska       79.6                               71.82   both
# 28                Nevada       78.4                               70.79   both
# 29         New Hampshire       80.1                               78.35   both
# 30            New Jersey       80.5                               73.98   both
# 31            New Mexico       78.4                               71.45   both
# 32              New York       81.0                               73.48   both
# 33        North Carolina       78.1                               73.56   both
# 34          North Dakota       79.7                               71.99   both
# 35                  Ohio       77.6                               72.01   both
# 36              Oklahoma       75.8                               68.58   both
# 37                Oregon       79.6                               75.82   both
# 38          Pennsylvania       78.6                               75.06   both
# 39          Rhode Island       79.9                               74.74   both
# 40        South Carolina       77.0                               70.88   both
# 41          South Dakota       79.4                               73.32   both
# 42             Tennessee       76.3                               72.68   both
# 43                 Texas       78.8                               69.73   both
# 44                  Utah       79.8                               75.69   both
# 45               Vermont       80.0                               78.95   both
# 46              Virginia       79.4                               74.12   both
# 47            Washington       80.3                               75.95   both
# 48         West Virginia       75.3                               68.49   both
# 50               Wyoming       78.8                               73.87   both

# %%
scatterPlotAndLine(x=merged_fruits_table.Longevity, y=merged_fruits_table.fruitsVegetablesConsumptionPercent, 
                   title="Fruits and Vegetable Consumption and Life Expectancy by State", y_label="Fruits and Vegetable Consumption Percentage", 
                   x_label="Life Expectancy at Birth (years)")

# %%
computeModelSummary(x=merged_fruits_table.Longevity, y=merged_fruits_table.fruitsVegetablesConsumptionPercent)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                          OLS Regression Results
# =======================================================================================================
# Dep. Variable:     fruitsVegetablesConsumptionPercent   R-squared (uncentered):                   0.999
# Model:                                            OLS   Adj. R-squared (uncentered):              0.999
# Method:                                 Least Squares   F-statistic:                          6.409e+04
# Date:                                Fri, 10 Jan 2020   Prob (F-statistic):                    1.09e-76
# Time:                                        16:11:57   Log-Likelihood:                         -103.36
# No. Observations:                                  49   AIC:                                      208.7
# Df Residuals:                                      48   BIC:                                      210.6
# Df Model:                                           1
# Covariance Type:                            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Longevity      0.9253      0.004    253.154      0.000       0.918       0.933
# ==============================================================================
# Omnibus:                        1.682   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.431   Jarque-Bera (JB):                0.900
# Skew:                           0.273   Prob(JB):                        0.638
# Kurtosis:                       3.377   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
